# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from time import time

# %%
df = pd.read_csv("../../data/microsoft_verified_users/verified_MSFT-textblob.csv", parse_dates = True, index_col = 'Date')
del df['Unnamed: 0']
del df['Unnamed: 0.1']
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2009-09-21   25.110001   25.370001   25.100000   25.299999   19.717058
# 2009-09-22   25.400000   25.820000   25.290001   25.770000   20.083347
# 2009-09-23   25.920000   26.250000   25.639999   25.709999   20.036585
# 2009-09-24   25.920000   26.110001   25.660000   25.940001   20.215834
# 2009-09-25   25.690001   25.820000   25.520000   25.549999   19.911896
# ...                ...         ...         ...         ...         ...
# 2020-05-24  183.190002  184.460007  182.539993  183.509995  183.509995
# 2020-05-25  183.190002  184.460007  182.539993  183.509995  183.509995
# 2020-05-26  186.339996  186.500000  181.100006  181.570007  181.570007
# 2020-05-27  180.199997  181.990005  176.600006  181.809998  181.809998
# 2020-05-28  180.740005  184.149994  180.380005  181.399994  181.399994
#
#               Volume  textblob_sentiment
# Date
# 2009-09-21  28878700            0.195671
# 2009-09-22  61376700            0.309491
# 2009-09-23  60599900           -0.042415
# 2009-09-24  56302900            0.052077
# 2009-09-25  50158900            0.060000
# ...              ...                 ...
# 2020-05-24  20826900            0.171746
# 2020-05-25  20826900            0.121714
# 2020-05-26  36073600            0.100771
# 2020-05-27  39517100            0.120277
# 2020-05-28  33810200            0.238808
#
# [3903 rows x 7 columns]

# %%
df.drop(columns=['Volume','Adj Close'],inplace=True)

# %%
df.columns = [['open', 'high', 'low','close','sentiment']]
df.corr()
# Out:
#                open      high       low     close sentiment
# open       1.000000  0.999805  0.999816  0.999668  0.032546
# high       0.999805  1.000000  0.999636  0.999806  0.032298
# low        0.999816  0.999636  1.000000  0.999784  0.032818
# close      0.999668  0.999806  0.999784  1.000000  0.032755
# sentiment  0.032546  0.032298  0.032818  0.032755  1.000000

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()

# %%
data = sc.fit_transform(df)

# %%
train_ind = int(0.6*len(df))
val_ind = train_ind + int(0.2*len(df))
train = data[:train_ind]
val = data[train_ind:val_ind]
test = data[val_ind:]

# %%
xtrain,ytrain,xtest,ytest = train[:,:],train[:,3],test[:,:],test[:,3]
xtrain.shape, ytrain.shape,
# Out:
# ((2341, 5), (2341,))

# %%
lookback = 60
n_features = 5
train_len = len(xtrain) - lookback
test_len = len(xtest) - lookback
val_len = len(xval) - lookback

# %%
x_train = np.zeros((train_len, lookback, n_features))
y_train = np.zeros((train_len))
for i in range(train_len):
    ytemp = i+lookback
    x_train[i] = xtrain[i:ytemp]
    y_train[i] = ytrain[ytemp]
print("x_train", x_train.shape)
print("y_train", y_train.shape)
# Out:
# x_train (2281, 60, 5)
# y_train (2281,)

# %%
x_val = np.zeros((val_len, lookback, n_features))
y_val = np.zeros((val_len))
for i in range(val_len):
    ytemp = i+lookback
    x_val[i] = xval[i:ytemp]
    y_val[i] = yval[ytemp]
print("x_val", x_val.shape)
print("y_val", y_val.shape)
# Out:
# x_val (720, 60, 5)
# y_val (720,)

# %%
x_test = np.zeros((test_len, lookback, n_features))
y_test = np.zeros((test_len))
for i in range(test_len):
    ytemp = i+lookback
    x_test[i] = xtest[i:ytemp]
    y_test[i] = ytest[ytemp]
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_test (722, 60, 5)
# y_test (722,)

# %%
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import LSTM
from keras.optimizers import Adam
from time import time
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score

# %%
model = Sequential() 
model.add(LSTM(120,input_shape = (lookback, n_features), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))

# %%
model.compile(loss = 'mse', optimizer = 'adam')
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')

# %%
start = time()
print("start:",0)
model.fit(x_train,y_train, epochs = 50, batch_size=30, 
          validation_data=(x_val,y_val),verbose = 1, 
          shuffle = False, callbacks=[earlystop])
print("end:",time()-start)
# Out:
# start: 0
# Train on 2281 samples, validate on 720 samples
# Epoch 1/50
# 2281/2281 [==============================] - 6s 2ms/step - loss: 7.6973e-04 - val_loss: 0.0026
# Epoch 2/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 7.2021e-04 - val_loss: 0.0070
# Epoch 3/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 4/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 5.4875e-04 - val_loss: 0.0039
# Epoch 5/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 5.7996e-04 - val_loss: 0.0040
# Epoch 6/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 6.3476e-04 - val_loss: 0.0042
# Epoch 7/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 7.1462e-04 - val_loss: 0.0040
# Epoch 8/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 9.3179e-04 - val_loss: 0.0052
# Epoch 9/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 0.0014 - val_loss: 0.0125
# Epoch 10/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 0.0012 - val_loss: 0.0097
# Epoch 11/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 9.1954e-04 - val_loss: 0.0061
# Epoch 12/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 6.1082e-04 - val_loss: 0.0025
# Epoch 13/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.5578e-04 - val_loss: 3.1253e-04
# Epoch 14/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7252e-04 - val_loss: 7.4654e-04
# Epoch 15/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 6.6344e-05 - val_loss: 0.0012
# Epoch 16/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.2250e-05 - val_loss: 8.1002e-04
# Epoch 17/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 3.6930e-05 - val_loss: 6.4181e-04
# Epoch 18/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.8526e-05 - val_loss: 4.6242e-04
# Epoch 19/50
# 2281/2281 [==============================] - 4s 2ms/step - loss: 2.9015e-05 - val_loss: 3.4584e-04
# Epoch 20/50
# 2281/2281 [==============================] - 4s 2ms/step - loss: 2.6296e-05 - val_loss: 2.5448e-04
# Epoch 21/50
# 2281/2281 [==============================] - 4s 2ms/step - loss: 2.5625e-05 - val_loss: 1.8919e-04
# Epoch 22/50
# 2281/2281 [==============================] - 4s 2ms/step - loss: 2.4525e-05 - val_loss: 1.4205e-04
# Epoch 23/50
# 2281/2281 [==============================] - 4s 2ms/step - loss: 2.3839e-05 - val_loss: 1.0855e-04
# Epoch 24/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 2.3196e-05 - val_loss: 8.5204e-05
# Epoch 25/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.2660e-05 - val_loss: 6.9233e-05
# Epoch 26/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 2.2174e-05 - val_loss: 5.8573e-05
# Epoch 27/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1719e-05 - val_loss: 5.1676e-05
# Epoch 28/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1275e-05 - val_loss: 4.7426e-05
# Epoch 29/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0826e-05 - val_loss: 4.5063e-05
# Epoch 30/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0368e-05 - val_loss: 4.4119e-05
# Epoch 31/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9908e-05 - val_loss: 4.4312e-05
# Epoch 32/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9463e-05 - val_loss: 4.5392e-05
# Epoch 33/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9056e-05 - val_loss: 4.6976e-05
# Epoch 34/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8705e-05 - val_loss: 4.8523e-05
# Epoch 35/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8418e-05 - val_loss: 4.9507e-05
# Epoch 36/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8188e-05 - val_loss: 4.9645e-05
# Epoch 37/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8002e-05 - val_loss: 4.8921e-05
# Epoch 38/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7848e-05 - val_loss: 4.7511e-05
# Epoch 39/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7716e-05 - val_loss: 4.5681e-05
# Epoch 40/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7603e-05 - val_loss: 4.3734e-05
# Epoch 41/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7514e-05 - val_loss: 4.1966e-05
# Epoch 42/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7457e-05 - val_loss: 4.0638e-05
# Epoch 43/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7448e-05 - val_loss: 3.9975e-05
# Epoch 44/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7506e-05 - val_loss: 4.0226e-05
# Epoch 45/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7648e-05 - val_loss: 4.1771e-05
# Epoch 46/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7889e-05 - val_loss: 4.5249e-05
# Epoch 47/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8230e-05 - val_loss: 5.1612e-05
# Epoch 48/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8658e-05 - val_loss: 6.2006e-05
# Epoch 49/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9150e-05 - val_loss: 7.7530e-05
# Epoch 50/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9679e-05 - val_loss: 9.9016e-05
# end: 258.48431158065796

# %% [markdown]
# \];ln
# odel.history.history
# loss = pd.DataFrame(loss)
# loss.to_csv("losses/model1.csv")
# plt.plot(loss['loss'])
# plt.plot(loss['val_loss'])
# plt.savefig("losses/model1.png")

# %%
loss = model.history.history
plt.plot(loss['loss'])
plt.plot(loss['val_loss'])

# %%
y_pred = model.predict(x_test)

plt.figure(figsize=(20,10))
plt.plot( y_test, '.-', color='red', label='Real values', alpha=0.5)
plt.plot( y_pred, '.-', color='blue', label='Predicted values', alpha=1)
# plt.savefig("losses/model1_graph.png")

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9351851355541473

# %%
model.save("stock_sentiment_1.h5")

# %%
model.evaluate(x_test, y_test)
# Out:
# 722/722 [==============================] - 0s 565us/step
# 0.0004558119617487688

# %%
model = Sequential() 
model.add(LSTM(118,input_shape = (lookback, n_features), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))

# %%
model.compile(loss = 'mse', optimizer = 'adam')
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')

# %%
start = time()
print("start:",0)
model.fit(x_train,y_train, epochs = 50, batch_size=30, 
          validation_data=(x_val,y_val),verbose = 1, 
          shuffle = False, callbacks=[earlystop])
print("end:",time()-start)
# Out:
# start: 0
# Train on 2281 samples, validate on 720 samples
# Epoch 1/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 5.6012e-04 - val_loss: 0.0037
# Epoch 2/50
# 2281/2281 [==============================] - 6s 2ms/step - loss: 4.4438e-04 - val_loss: 0.0030
# Epoch 3/50
# 2281/2281 [==============================] - 6s 2ms/step - loss: 7.2014e-04 - val_loss: 0.0033
# Epoch 4/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 5.6489e-04 - val_loss: 0.0036
# Epoch 5/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 6.2038e-04 - val_loss: 0.0056
# Epoch 6/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 6.5863e-04 - val_loss: 0.0044
# Epoch 7/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 8.8497e-04 - val_loss: 0.0041
# Epoch 8/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0075
# Epoch 9/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 0.0012 - val_loss: 0.0079
# Epoch 10/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 8.5803e-04 - val_loss: 0.0040
# Epoch 11/50
# 2281/2281 [==============================] - 6s 2ms/step - loss: 4.8073e-04 - val_loss: 8.4421e-04
# Epoch 12/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.5375e-04 - val_loss: 3.7936e-04
# Epoch 13/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.0868e-04 - val_loss: 0.0020
# Epoch 14/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 4.6053e-05 - val_loss: 0.0015
# Epoch 15/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 4.2333e-05 - val_loss: 0.0011
# Epoch 16/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.7575e-05 - val_loss: 8.7405e-04
# Epoch 17/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.4452e-05 - val_loss: 6.6605e-04
# Epoch 18/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.1886e-05 - val_loss: 5.0550e-04
# Epoch 19/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.9990e-05 - val_loss: 3.8272e-04
# Epoch 20/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.8451e-05 - val_loss: 2.8942e-04
# Epoch 21/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.7230e-05 - val_loss: 2.1937e-04
# Epoch 22/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.6219e-05 - val_loss: 1.6750e-04
# Epoch 23/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.5365e-05 - val_loss: 1.2969e-04
# Epoch 24/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.4616e-05 - val_loss: 1.0264e-04
# Epoch 25/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.3929e-05 - val_loss: 8.3738e-05
# Epoch 26/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.3266e-05 - val_loss: 7.0929e-05
# Epoch 27/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.2595e-05 - val_loss: 6.2692e-05
# Epoch 28/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1893e-05 - val_loss: 5.7949e-05
# Epoch 29/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1152e-05 - val_loss: 5.5997e-05
# Epoch 30/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0391e-05 - val_loss: 5.6358e-05
# Epoch 31/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9654e-05 - val_loss: 5.8486e-05
# Epoch 32/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9002e-05 - val_loss: 6.1433e-05
# Epoch 33/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8484e-05 - val_loss: 6.3913e-05
# Epoch 34/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8110e-05 - val_loss: 6.4943e-05
# Epoch 35/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7853e-05 - val_loss: 6.4313e-05
# Epoch 36/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7672e-05 - val_loss: 6.2361e-05
# Epoch 37/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7537e-05 - val_loss: 5.9591e-05
# Epoch 38/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7433e-05 - val_loss: 5.6496e-05
# Epoch 39/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7356e-05 - val_loss: 5.3514e-05
# Epoch 40/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7313e-05 - val_loss: 5.1022e-05
# Epoch 41/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7313e-05 - val_loss: 4.9337e-05
# Epoch 42/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7374e-05 - val_loss: 4.8747e-05
# Epoch 43/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7511e-05 - val_loss: 4.9569e-05
# Epoch 44/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.7736e-05 - val_loss: 5.2228e-05
# Epoch 45/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8056e-05 - val_loss: 5.7297e-05
# Epoch 46/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8464e-05 - val_loss: 6.5455e-05
# Epoch 47/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8946e-05 - val_loss: 7.7334e-05
# Epoch 48/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9480e-05 - val_loss: 9.3374e-05
# Epoch 49/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0046e-05 - val_loss: 1.1370e-04
# Epoch 50/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0629e-05 - val_loss: 1.3812e-04
# end: 267.1478991508484

# %%
loss = model.history.history
loss = pd.DataFrame(loss)
loss.to_csv("losses/model8.csv")
plt.plot(loss['loss'])
plt.plot(loss['val_loss'])
plt.savefig("losses/model8.png")

# %%
y_pred = model.predict(x_test)

plt.figure(figsize=(20,10))
plt.plot( y_test, '.-', color='red', label='Real values', alpha=0.5)
plt.plot( y_pred, '.-', color='blue', label='Predicted values', alpha=1)
plt.savefig("losses/model8_graph.png")

# %%
model.save("stock_sentiment_8.h5")

# %%
model.evaluate(x_test, y_test)
# Out:
# 722/722 [==============================] - 0s 553us/step
# 0.002082419561717525

# %%
model = Sequential() 
model.add(LSTM(110,input_shape = (lookback, n_features), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))

# %%
model.compile(loss = 'mse', optimizer = 'adam')
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')

# %%
start = time()
print("start:",0)
model.fit(x_train,y_train, epochs = 50, batch_size=30, 
          validation_data=(x_val,y_val),verbose = 1, 
          shuffle = False, callbacks=[earlystop])
print("end:",time()-start)
# Out:
# start: 0
# Train on 2281 samples, validate on 720 samples
# Epoch 1/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 5.6699e-04 - val_loss: 0.0031
# Epoch 2/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 8.8819e-04 - val_loss: 0.0028
# Epoch 3/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 8.5413e-04 - val_loss: 0.0030
# Epoch 4/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 9.7023e-04 - val_loss: 0.0028
# Epoch 5/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 6/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 0.0012 - val_loss: 0.0073
# Epoch 7/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 9.1580e-04 - val_loss: 0.0042
# Epoch 8/50
# 2281/2281 [==============================] - 7s 3ms/step - loss: 5.6689e-04 - val_loss: 7.2057e-04
# Epoch 9/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 2.5404e-04 - val_loss: 3.9400e-04
# Epoch 10/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 9.5147e-05 - val_loss: 0.0018
# Epoch 11/50
# 2281/2281 [==============================] - 6s 3ms/step - loss: 4.0032e-05 - val_loss: 0.0013
# Epoch 12/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.8108e-05 - val_loss: 0.0010
# Epoch 13/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.6194e-05 - val_loss: 7.8789e-04
# Epoch 14/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.4199e-05 - val_loss: 6.1083e-04
# Epoch 15/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.2976e-05 - val_loss: 4.7355e-04
# Epoch 16/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.1936e-05 - val_loss: 3.6733e-04
# Epoch 17/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.1171e-05 - val_loss: 2.8593e-04
# Epoch 18/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.0556e-05 - val_loss: 2.2429e-04
# Epoch 19/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 3.0048e-05 - val_loss: 1.7817e-04
# Epoch 20/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.9583e-05 - val_loss: 1.4420e-04
# Epoch 21/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.9099e-05 - val_loss: 1.1972e-04
# Epoch 22/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.8523e-05 - val_loss: 1.0274e-04
# Epoch 23/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.7782e-05 - val_loss: 9.1879e-05
# Epoch 24/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.6802e-05 - val_loss: 8.6434e-05
# Epoch 25/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.5534e-05 - val_loss: 8.6252e-05
# Epoch 26/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.3995e-05 - val_loss: 9.1449e-05
# Epoch 27/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.2320e-05 - val_loss: 1.0100e-04
# Epoch 28/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0772e-05 - val_loss: 1.1096e-04
# Epoch 29/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9618e-05 - val_loss: 1.1599e-04
# Epoch 30/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8935e-05 - val_loss: 1.1449e-04
# Epoch 31/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8591e-05 - val_loss: 1.0882e-04
# Epoch 32/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8416e-05 - val_loss: 1.0167e-04
# Epoch 33/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8318e-05 - val_loss: 9.4740e-05
# Epoch 34/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8269e-05 - val_loss: 8.8994e-05
# Epoch 35/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8272e-05 - val_loss: 8.5096e-05
# Epoch 36/50
# 2281/2281 [==============================] - 6s 2ms/step - loss: 1.8345e-05 - val_loss: 8.3632e-05
# Epoch 37/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8507e-05 - val_loss: 8.5216e-05
# Epoch 38/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.8776e-05 - val_loss: 9.0572e-05
# Epoch 39/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9156e-05 - val_loss: 1.0051e-04
# Epoch 40/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 1.9635e-05 - val_loss: 1.1575e-04
# Epoch 41/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0181e-05 - val_loss: 1.3669e-04
# Epoch 42/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.0758e-05 - val_loss: 1.6328e-04
# Epoch 43/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1331e-05 - val_loss: 1.9507e-04
# Epoch 44/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.1882e-05 - val_loss: 2.3132e-04
# Epoch 45/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.2403e-05 - val_loss: 2.7114e-04
# Epoch 46/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.2897e-05 - val_loss: 3.1353e-04
# Epoch 47/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.3367e-05 - val_loss: 3.5738e-04
# Epoch 48/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.3819e-05 - val_loss: 4.0151e-04
# Epoch 49/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.4257e-05 - val_loss: 4.4472e-04
# Epoch 50/50
# 2281/2281 [==============================] - 5s 2ms/step - loss: 2.4681e-05 - val_loss: 4.8574e-04
# end: 269.64607429504395

# %%
loss = model.history.history
loss = pd.DataFrame(loss)
loss.to_csv("losses/model10.csv")
plt.plot(loss['loss'])
plt.plot(loss['val_loss'])
plt.savefig("losses/model10.png")

# %%
y_pred = model.predict(x_test)

plt.figure(figsize=(20,10))
plt.plot( y_test, '.-', color='red', label='Real values', alpha=0.5)
plt.plot( y_pred, '.-', color='blue', label='Predicted values', alpha=1)
plt.savefig("losses/model10_graph.png")

# %%
model.save("stock_sentiment_10.h5")

# %%
model.evaluate(x_test, y_test)
# Out:
# 722/722 [==============================] - 0s 514us/step
# 0.012783467645790438

# %%
model1 = load_model("stock_sentiment_1.h5")
model11 = load_model("stock_sentiment_11.h5")

# %%
model1.evaluate(x_test,y_test)
# Out:
# 722/722 [==============================] - 0s 547us/step
# 0.0014917453431067705

# %%
results_original = pd.read_csv("../stock_prediction/without_sentiment.csv")

# %%
results_original
# Out:
#     Unnamed: 0         0
# 0            0  0.000373
# 1            1  0.005508
# 2            2  0.001133
# 3            3  0.009937
# 4            4  0.004588
# 5            5  0.000835
# 6            6  0.013204
# 7            7  0.000327
# 8            8  0.005302
# 9            9  0.000360
# 10          10  0.000334

# %%
model11.evaluate(x_test,y_test)
# Out:
# 722/722 [==============================] - 0s 565us/step
# 0.0007189869612372813
