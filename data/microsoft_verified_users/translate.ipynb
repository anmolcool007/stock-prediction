# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# dataset			       movieReviewSentiment.ipynb  temp.ipynb
# microsoft_verified_tweets.csv  preprocess2.py		   translated.csv
# mixedlang.csv		       sentiment.ipynb

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/preprocess2.py"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/My Drive/Colab Notebooks/preprocess2.py", line 5, in <module>
#     df = pd.read_csv("microsoft_verified_tweets.csv")
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 676, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 448, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 880, in __init__
#     self._make_engine(self.engine)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1114, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1891, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 374, in pandas._libs.parsers.TextReader.__cinit__
# ...

# %%
# !pip install googletrans

# %%
import pandas as pd
import sys
import time
# from googletrans import Translator
# trans = Translator()

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/translated.csv",usecols = ['date','tweet'])
# trans.translate("Ihr lese ein Zeitung").text
df.tail(20)
# df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
#                        date                                              tweet
# 274502  2009-01-10 18:15:00  Arghhhh, Windows 7 download has stopped at 900...
# 274503  2009-01-08 09:09:00  Retweeting davidcrow: Kodu = Boku from PDC =  ...
# 274504  2009-01-06 16:40:20  CWCF: First speakers from Pixelpark, Microsoft...
# 274505  2008-12-30 23:13:17  brycej Ahhh, one of the best benes of working ...
# 274506  2008-12-23 19:23:31  Douglas Purdy says, "On Vacation? Invent your ...
# 274507  2008-12-17 18:03:27  grayle Even more curious: Kumo means "spider" ...
# 274508  2008-12-12 16:32:37  Blog: Microsoft Windows on the Cloud released ...
# 274509  2008-12-09 19:25:22  The politician is the only one who does not ac...
# 274510  2008-11-30 15:25:12  rtwt: csommer New rumors regarding Microsoft Y...
# 274511  2008-11-27 15:50:14  hediger Ha, also wanted to go, but then unfort...
# 274512  2008-11-14 06:30:22  Unsealed docs from Vista Capable class-action ...
# ...

# %%
tweets = df.tweet.tolist() #27540 length
len(tweets)
start = time.time()
for i in range(4444,8888):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    print(i,time.time()-start)
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# 4444 0.11454534530639648
# 4445 0.37372684478759766
# 4446 0.665687084197998
# 4447 0.948462724685669
# 4448 1.2326459884643555
# 4449 1.466766119003296
# 4450 1.7149460315704346
# 4451 1.8591229915618896
# 4452 2.057007312774658
# 4453 2.305347442626953
# 4454 2.4537172317504883
# 4455 2.9529948234558105
# 4456 3.0873591899871826
# 4457 3.4008541107177734
# 4458 3.7369325160980225
# 4459 3.8831677436828613
# 4460 4.01318097114563
# 4461 4.345289945602417
# 4462 4.521026372909546
# 4463 4.699526786804199
# 4464 4.9799299240112305
# 4465 5.244865655899048
# 4466 5.358955144882202
# 4467 5.498521089553833
# 4468 5.6664934158325195
# 4469 6.061523914337158
# 4470 6.321160316467285
# 4471 6.450495004653931
# 4472 6.687453508377075
# 4473 6.806379079818726
# 4474 6.9621241092681885
# 4475 7.087984085083008
# 4476 7.241850137710571
# 4477 8.817946434020996
# 4478 9.112921237945557
# 4479 9.256239891052246
# 4480 9.389474391937256
# 4481 9.582977533340454
# 4482 9.699354648590088
# ...

# %%
tweets = df.tweet.tolist() #27540 length
len(tweets)
start = time.time()
for i in range(8888,13332):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    print(i,time.time()-start)
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# 8888 0.12488508224487305
# 8889 0.26905274391174316
# 8890 0.4300985336303711
# 8891 0.5782139301300049
# 8892 0.745898962020874
# 8893 0.8664767742156982
# 8894 1.0711441040039062
# 8895 1.3816614151000977
# 8896 1.4932100772857666
# 8897 1.6276931762695312
# 8898 1.7702419757843018
# 8899 2.0144593715667725
# 8900 2.2054576873779297
# 8901 2.5862395763397217
# 8902 2.8387491703033447
# 8903 3.0534703731536865
# 8904 3.169145107269287
# 8905 3.411565065383911
# 8906 3.508890390396118
# 8907 3.6201982498168945
# 8908 3.909559965133667
# 8909 4.0543434619903564
# 8910 4.168757438659668
# 8911 4.445955038070679
# 8912 4.6916704177856445
# 8913 4.796686172485352
# 8914 4.915072202682495
# 8915 5.031766891479492
# 8916 5.342284917831421
# 8917 5.467297554016113
# 8918 5.633954048156738
# 8919 5.804130792617798
# 8920 5.9601054191589355
# 8921 6.1492226123809814
# 8922 6.274435758590698
# 8923 6.450537919998169
# 8924 6.592952013015747
# 8925 6.824703931808472
# 8926 6.991758108139038
# ...

# %%
tweets = df.tweet.tolist() #27540 length
len(tweets)
start = time.time()
for i in range(13332,18332):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    print(i,time.time()-start)
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# 13333 0.5252053737640381
# 13334 0.6274106502532959
# 13335 0.900681734085083
# 13336 1.0467274188995361
# 13337 1.1910123825073242
# 13338 1.4545056819915771
# 13339 1.652719259262085
# 13340 1.8230133056640625
# 13341 2.0846235752105713
# 13342 2.242882251739502
# 13343 2.3814306259155273
# 13344 2.6639723777770996
# 13345 2.7983968257904053
# 13346 2.9214565753936768
# 13347 3.048774242401123
# 13348 3.1755268573760986
# 13349 3.5946035385131836
# 13350 3.8142995834350586
# 13351 4.0457923412323
# 13352 4.28569221496582
# 13353 4.561105489730835
# 13354 4.715538263320923
# 13355 4.9450507164001465
# 13356 5.458105564117432
# 13357 6.536081314086914
# 13358 6.817236661911011
# 13359 7.022257089614868
# 13360 7.17663836479187
# 13361 7.325802803039551
# 13362 7.564119338989258
# 13363 7.685489892959595
# 13364 7.814460039138794
# 13365 8.150353193283081
# 13366 8.369933843612671
# 13367 8.604005575180054
# 13368 8.8456552028656
# ...

# %%
tweets = df.tweet.tolist() #27522 length
len(tweets)
start = time.time()
for i in range(18332,23332):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    print(i,time.time()-start)
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# 18333 0.5364632606506348
# 18334 0.8372094631195068
# 18335 1.083564281463623
# 18336 1.3104565143585205
# 18337 1.5663504600524902
# 18338 1.6985671520233154
# 18339 1.8437623977661133
# 18340 1.970693826675415
# 18341 2.0848593711853027
# 18342 2.3711721897125244
# 18343 2.624544620513916
# 18344 2.8108768463134766
# 18345 3.065718412399292
# 18346 3.184171438217163
# 18347 3.335136890411377
# 18348 3.4889233112335205
# 18349 3.5994646549224854
# 18350 3.9353084564208984
# 18351 4.246954917907715
# 18352 4.408420562744141
# 18353 4.649763822555542
# 18354 4.858839511871338
# 18355 5.020887851715088
# 18356 5.195430517196655
# 18357 5.384339809417725
# 18358 5.507229328155518
# 18359 5.6642584800720215
# 18360 5.8023741245269775
# 18361 5.914872407913208
# 18362 6.073200941085815
# 18363 6.243051528930664
# 18364 6.380917310714722
# 18365 6.51530647277832
# 18366 6.656692743301392
# 18367 6.812267065048218
# ...

# %%
tweets = df.tweet.tolist() #27522 length
len(tweets)
start = time.time()
for i in range(23332,100000):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    print(i,time.time()-start)
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# 95001 12911.840398550034
# 95002 12912.014935731888
# 95003 12912.150522708893
# 95004 12912.271728038788
# 95005 12912.407922506332
# 95006 12912.56571650505
# 95007 12912.77724313736
# 95008 12912.923560857773
# 95009 12913.145512104034
# 95010 12913.300647735596
# 95011 12913.553600549698
# 95012 12913.700137138367
# 95013 12913.8609957695
# 95014 12913.966285467148
# 95015 12914.125571250916
# 95016 12914.254757642746
# 95017 12914.524686098099
# 95018 12914.763563871384
# 95019 12914.950836658478
# 95020 12915.10296678543
# 95021 12915.389808893204
# 95022 12915.557656288147
# 95023 12915.672850131989
# 95024 12915.966705083847
# 95025 12916.095310211182
# 95026 12916.262177944183
# 95027 12916.390887022018
# 95028 12916.519264698029
# 95029 12916.661321401596
# 95030 12916.87395954132
# 95031 12917.367403745651
# 95032 12917.538024425507
# 95033 12917.677556037903
# 95034 12917.936829805374
# 95035 12918.19526720047
# ...

# %%
tweets = df.tweet.tolist() #27522 length
len(tweets)
start = time.time()
for i in range(100000,len(df)):
    trans = Translator()
    tweets[i] = trans.translate(str(tweets[i])).text
    if i%1000==0:
      df['tweet'] = tweets
      df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
    print(i,time.time()-start)
    
df['tweet'] = tweets
df.to_csv("/content/drive/My Drive/Colab Notebooks/translated.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# 269523 22097.369737386703
# 269524 22097.507879972458
# 269525 22097.657229423523
# 269526 22097.79517698288
# 269527 22097.950476646423
# 269528 22098.087177038193
# 269529 22098.254259109497
# 269530 22098.390116930008
# 269531 22098.538628816605
# 269532 22098.66999745369
# 269533 22098.784772872925
# 269534 22098.956005096436
# 269535 22099.10916495323
# 269536 22099.240111112595
# 269537 22099.40089249611
# 269538 22099.537328481674
# 269539 22099.678133010864
# 269540 22099.908851861954
# 269541 22100.05854535103
# 269542 22100.217606306076
# 269543 22100.377848386765
# 269544 22100.534393310547
# 269545 22100.704798460007
# 269546 22100.912555217743
# 269547 22101.0702753067
# 269548 22101.223756074905
# 269549 22101.369555950165
# 269550 22101.52007126808
# 269551 22101.656457424164
# 269552 22101.8138859272
# 269553 22101.9714884758
# 269554 22102.147795677185
# 269555 22102.297786474228
# 269556 22102.451809167862
# ...

# %%
ADHIP/0
